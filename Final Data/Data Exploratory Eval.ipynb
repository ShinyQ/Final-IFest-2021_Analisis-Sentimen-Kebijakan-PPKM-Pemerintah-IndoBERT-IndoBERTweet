# %%
# Optional
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/Shareddrives/DAC UNPAD: Yaudahlah/FINAL MENANG BISMILLAH/Final Data/eval_data.csv")

# %%
len(df)
# Out:
# 1962

# %%
df[df['prediction'] != df['label']]
# Out:
#                                                     raw  ... prediction
# 3     @expmbd 30-34an derajat, alasan untuk gk kelua...  ...          0
# 41    @Cindysa47160006 Harus semngt terus ya smpe pp...  ...          1
# 43    Tadinya mau beli barang di toko online, baru i...  ...          1
# 50    Progres penyaluran bantuan desa prosentase 44,...  ...          2
# 52    @chetrries risol tu kenapa enak banget?! terut...  ...          1
# ...                                                 ...  ...        ...
# 1944          @fatshasubandy @txtdarigajelas skip ppkm🙏  ...          0
# 1948  @AditTaqwa tolong pak ppkm jngn di perpanjang ...  ...          0
# 1952  @rmol_id @airlangga_hrt PPKM, masa aktivitas w...  ...          0
# 1955  Update peraturan yg ketinggalan dan level PPKM...  ...          1
# 1957  Hikmah dari uang yang masih nyisa banyak akiba...  ...          2
#
# [305 rows x 4 columns]
